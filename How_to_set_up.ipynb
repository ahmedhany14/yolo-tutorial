# %% [markdown]
# # [Set up YOLO]()

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.pt")

# %% [markdown]
# # [Get results]()

# %%
# !yolo predict model=/home/hany_jr/Ai/yolo-tutorial/yolov8s.pt source='/home/hany_jr/Downloads/wallpaperflare.com_wallpaper.jpg' conf=0.25 iou=0.45

# show results
from IPython.display import Image
Image(filename='/home/hany_jr/Ai/yolo-tutorial/runs/detect/predict/wallpaperflare.com_wallpaper.jpg')
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 7932MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /home/hany_jr/Downloads/wallpaperflare.com_wallpaper.jpg: 384x640 1 person, 29.2ms
# Speed: 1.9ms preprocess, 29.2ms inference, 287.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
