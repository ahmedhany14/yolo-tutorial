# %% [markdown]
# # Video tacking

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.pt")

# %%
result = model("/home/hany_jr/Downloads/WhatSie/WhatsApp Video 2024-08-29 at 2.55.35 AM.mp4", show=True)
# Out:
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# QObject::moveToThread: Current thread (0x9976430) is not the object's thread (0x8ffedd0).
# Cannot move to target thread (0x9976430)
#
# ...

# %% [markdown]
# # Segmentation

# %%
# !yolo predict model=/home/hany_jr/Ai/yolo-tutorial/yolov8n-seg.pt source='/home/hany_jr/Downloads/images.jpeg' conf=0.25 iou=0.45
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.12.4 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 7932MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /home/hany_jr/Downloads/images.jpeg: 288x640 8 persons, 3 cars, 2 traffic lights, 1 potted plant, 32.3ms
# Speed: 1.2ms preprocess, 32.3ms inference, 285.6ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image

Image(filename='/home/hany_jr/Ai/yolo-tutorial/runs/segment/predict/images.jpeg', width=1000)
